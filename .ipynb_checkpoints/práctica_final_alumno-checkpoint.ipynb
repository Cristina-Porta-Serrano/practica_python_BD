# %%
import pandas as pd

# %% [markdown]
# Cargar datos

# %%
# Importamos el dataset de los datos de los pokemon

pokemon = pd.read_csv('dataset_final.csv') # No especifico el delimiter porque por defecto es coma
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
'''
1. ¿Cuántos pokémon hay en el dataset?
'''
pokemon['Name'].nunique()
# Out:
# 800

# %%
'''
2. ¿Cuántos pokémon hay de tipo Poison? (Type 1)
'''
len(pokemon[pokemon['Type 1'] == 'Poison'])
# Out:
# 28

# %%
'''
3. ¿Cuántos tipos diferentes de pokémon hay? (Type 1)
'''
pokemon['Type 1'].nunique()
# Out:
# 18

# %%
'''
2. ¿Cuántos pokémon hay de cada tipo? (Type 1)
'''
pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
'''
2.1 ¿cual es el tipo de pokémon con más pokémon? (Type 1)
'''
pokemon['Type 1'].max()
# Out:
# 'Water'

# %%
'''
3. ¿Cuál es el pokémon más rápido?
'''
# index corresponding max value
i = pokemon['Speed'].idxmax()
pokemon['Name'][i]
# Out:
# 'DeoxysSpeed Forme'

# %%
'''
4. ¿Cuántos pokemon tiene una defensa superior a 100?
'''
len(pokemon[pokemon['Defense'] > 100])
# Out:
# 123

# %%
'''
4.1 ¿Cuántos pokemon tiene una defensa superior a 100?
'''
# Out:
# '\n4.1 ¿Cuántos pokemon tiene una defensa superior a 100?\n'

# %%
'''
5. ¿Cuántos pokemon tiene una defensa superior a 100 y una velocidad superior a 100?
'''
len(pokemon[(pokemon['Defense'] > 100) & (pokemon['Speed'] > 100)])
# Out:
# 9

# %%
'''
6. Ordena el dataset por el tipo 1 y por el tipo 2
'''
pokemon.sort_values(['Type 1', 'Type 2'], ascending = [True, True])
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 656  595                   Joltik    Bug  Electric    319   50      47
# 657  596               Galvantula    Bug  Electric    472   70      77
# 231  214                Heracross    Bug  Fighting    500   80     125
# 232  214  HeracrossMega Heracross    Bug  Fighting    600   80     185
# 697  636                 Larvesta    Bug      Fire    360   55      85
# ..   ...                      ...    ...       ...    ...  ...     ...
# 655  594                Alomomola  Water       NaN    470  165      75
# 724  656                  Froakie  Water       NaN    314   41      56
# 725  657                Frogadier  Water       NaN    405   54      63
# 762  692                Clauncher  Water       NaN    330   50      53
# 763  693                Clawitzer  Water       NaN    500   71      73
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 656       50       57       50     65           5      False
# 657       60       97       60    108           5      False
# 231       75       40       95     85           2      False
# 232      115       40      105     75           2      False
# 697       55       50       55     60           5      False
# ..       ...      ...      ...    ...         ...        ...
# 655       80       40       45     65           5      False
# 724       40       62       44     71           6      False
# 725       52       83       56     97           6      False
# 762       62       58       63     44           6      False
# 763       88      120       89     59           6      False
#
# [800 rows x 13 columns]

# %%
'''
7. Crea un nuevo dataset con los pokémon de tipo Water y Fire como primer tipo
'''
pokemon_water_fire = pd.DataFrame(pokemon.loc[(pokemon['Type 1'] == 'Water') | (pokemon['Type 1'] == 'Fire')])

pokemon_water_fire.sort_values(by='Type 1', ascending=False)
# Out:
#        #        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 301  278     Wingull  Water    Flying    270   40      30       30       55
# 655  594   Alomomola  Water       NaN    470  165      75       80       40
# 595  535     Tympole  Water       NaN    294   50      50       40       50
# 596  536   Palpitoad  Water    Ground    384   75      65       55       65
# 597  537  Seismitoad  Water    Ground    509  105      95       75       85
# ..   ...         ...    ...       ...    ...  ...     ...      ...      ...
# 278  257    Blaziken   Fire  Fighting    530   80     120       70      110
# 277  256   Combusken   Fire  Fighting    405   60      85       60       85
# 276  255     Torchic   Fire       NaN    310   45      60       40       70
# 270  250       Ho-oh   Fire    Flying    680  106     130       90      110
# 799  721   Volcanion   Fire     Water    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 301       30     85           3      False
# 655       45     65           5      False
# 595       40     64           5      False
# 596       55     69           5      False
# 597       75     74           5      False
# ..       ...    ...         ...        ...
# 278       70     80           3      False
# 277       60     55           3      False
# 276       50     45           3      False
# 270      154     90           2       True
# 799       90     70           6       True
#
# [164 rows x 13 columns]

# %%
'''
8. Crea un nuevo dataset con los pokemon Legendary
'''
pokemon_legendary = pd.DataFrame(pokemon.loc[pokemon['Legendary'] == True])
pokemon_legendary
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True
# ..       ...      ...      ...    ...         ...        ...
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [65 rows x 13 columns]

# %%
'''
9. Calcula el promedio de stats de los pokemon Legendary (HP, Attack, Defense, Sp. Atk, Sp. Def, Speed) y los no Legendary
'''
pokemon.groupby(["Legendary"])['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'].mean().round(2)
# Out:
# C:\Users\Pereira\AppData\Local\Temp/ipykernel_5228/1124142395.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pokemon.groupby(["Legendary"])['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'].mean().round(2)
#               HP  Attack  Defense  Sp. Atk  Sp. Def   Speed
# Legendary
# False      67.18   75.67    71.56    68.45    68.89   65.46
# True       92.74  116.68    99.66   122.18   105.94  100.18

# %%
'''
10. Crea un nuevo dataframe con el resultado del anterior ejercicio comparando ambos promedios

ejemplo:
                HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
Legendary       99      90       89       91       94     90
No Legendary    80      95       75       12       43     87

'''
pokemon_stats_df = pd.DataFrame(pokemon.groupby(["Legendary"])['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'].mean().round(2))
pokemon_stats_df
# Out:
# C:\Users\Pereira\AppData\Local\Temp/ipykernel_5228/976560282.py:10: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pokemon_stats_df = pd.DataFrame(pokemon.groupby(["Legendary"])['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'].mean().round(2))
#               HP  Attack  Defense  Sp. Atk  Sp. Def   Speed
# Legendary
# False      67.18   75.67    71.56    68.45    68.89   65.46
# True       92.74  116.68    99.66   122.18   105.94  100.18

# %%
'''
11. Añade una nueva colunma ['Doble tipo'] al dataframe inicial que inndique si el pokemo tiene dos tipos o no
'''

pokemon.loc[pokemon['Type 2'].isnull(), 'Doble Tipo'] = 'False' 
pokemon.loc[pokemon['Type 2'].notnull(), 'Doble Tipo'] = 'True'

pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary Doble Tipo
# 0         65       65     45           1      False       True
# 1         80       80     60           1      False       True
# 2        100      100     80           1      False       True
# 3        122      120     80           1      False       True
# 4         60       50     65           1      False      False
# ..       ...      ...    ...         ...        ...        ...
# 795      100      150     50           6       True       True
# 796      160      110    110           6       True       True
# 797      150      130     70           6       True       True
# 798      170      130     80           6       True       True
# 799      130       90     70           6       True       True
#
# [800 rows x 14 columns]

# %%
'''
12. Muestra las columas Name, Type 1, Type 2 de los pokémon que tienen dos tipos y ordenalos por Type 1 , Type 2 y Name
'''
pokemon[['Type 1', 'Type 2', 'Name']][pokemon['Doble Tipo'] == 'True'].sort_values(by=['Type 1', 'Type 2', 'Name'], 
                                                                                   ascending=[True, True, True])
# Out:
#     Type 1    Type 2                     Name
# 657    Bug  Electric               Galvantula
# 656    Bug  Electric                   Joltik
# 231    Bug  Fighting                Heracross
# 232    Bug  Fighting  HeracrossMega Heracross
# 697    Bug      Fire                 Larvesta
# ..     ...       ...                      ...
# 626  Water      Rock               Carracosta
# 240  Water      Rock                  Corsola
# 404  Water      Rock                Relicanth
# 625  Water      Rock                 Tirtouga
# 440  Water     Steel                 Empoleon
#
# [414 rows x 3 columns]

# %%
from functools import reduce

'''
13. Dada una lista de Artículos con sus precio. Define las siguientes funciones:
Puedes definir más funciones si lo consideras necesario.
'''
articulos = {
    'Camisa': 20,
    'Pantalón': 30,
    'Calcetines': 5,
    'Zapatos': 50,
    'Gorra': 10,
    'Bufanda': 15,
    'Gafas': 25,
    'Reloj': 35,
    'Corbata': 40,
}

compra = ['Camisa', 'Pantalón', 'Pantalón', 'Gorra', 'Gafas', 'Corbata']

# %%
# A. Una función que calcule el precio total de la compra

compra_art = []

list(map(lambda x: compra_art.append(articulos[x]), compra))

compra_art

sum_total = reduce(lambda x, y  : x + y, compra_art)       
sum_total
# Out:
# 155

# %%
# B. Una función que calcule el precio total de la compra con un descuento del 10%

sum_total_disc = reduce(lambda x, y: x + y, list(map(lambda x: x*0.9, compra_art)))
sum_total_disc
# Out:
# 139.5

# %%
# C. Una función que calcule el precio total de la compra con un descuento del 10% si la compra supera los 100€

if sum_total > 100:
    sum_total_disc_2 = reduce(lambda x, y: x + y, list(map(lambda x: x*0.9, compra_art)))
    
sum_total_disc_2
# Out:
# 139.5

# %%
# D. Una función que calcule el precio total aplicando el IVA (21%)
sum_total_iva = reduce(lambda x, y: x + y, list(map(lambda x: x*1.21, compra_art)))
sum_total_iva
# Out:
# 187.54999999999998

# %%
# E.lista los artículos cuyo precio es superior a 20€

filtra_20 = lambda x: x[1] > 20

dict(filter(filtra_20, articulos.items()))
# Out:
# {'Pantalón': 30, 'Zapatos': 50, 'Gafas': 25, 'Reloj': 35, 'Corbata': 40}

# %%
'''
14. Dada una lista de tuplas con el nombre de un alumno, apellidos, curso y sus notas. 

 Define una funcion que reciba el curso y saque una lista en la que aparezca e nombre y apellidos y el promedio de sus notas.
 Puedes definir más funciones si lo consideras necesario.
'''

alumnos = [('Juan', 'Pérez', '1', [5, 6, 7, 8, 9]),
            ('Ana', 'García', '2', [5, 6, 7, 8, 9]),
            ('Luis', 'González', '1', [5, 6, 7, 8, 9]),
            ('María', 'Martínez', '2', [5, 6, 7, 8, 9]),
            ('Pedro', 'Rodríguez', '1', [5, 6, 7, 8, 9]),
            ('Lucía', 'Hernández', '2', [5, 6, 7, 8, 9]),
            ('Marta', 'López', '1', [5, 6, 7, 8, 9]),
            ('Sara', 'Díaz', '2', [5, 6, 7, 8, 9]),
            ('Javier', 'Sánchez', '1', [5, 6, 7, 8, 9]),
            ('Miguel', 'Fernández', '2', [5, 6, 7, 8, 9]),
            ('Sergio', 'Jiménez', '1', [5, 6, 7, 8, 9]),
            ('Sandra', 'Ruiz', '2', [5, 6, 7, 8, 9]),
            ('Pablo', 'Álvarez', '1', [5, 6, 7, 8, 9]),
            ('María', 'Gómez', '2', [5, 6, 7, 8, 9]),
]

# %%
curso = '1' #variable para pedir el curso, cambiala aqui


alumnos_del_curso = [list(alumno) for alumno in alumnos if alumno[2] == curso]
media_notas  = lambda x : sum(x[3])/len(x[3])

notas_medias_list = list(map(media_notas, alumnos_del_curso))

list(map(lambda x, y: x.append(y), alumnos_del_curso, notas_medias_list))

list(map(lambda x : x.pop(3) and x.pop(2), alumnos_del_curso))

alumnos_del_curso
# Out:
# [['Juan', 'Pérez', 7.0],
#  ['Luis', 'González', 7.0],
#  ['Pedro', 'Rodríguez', 7.0],
#  ['Marta', 'López', 7.0],
#  ['Javier', 'Sánchez', 7.0],
#  ['Sergio', 'Jiménez', 7.0],
#  ['Pablo', 'Álvarez', 7.0]]
